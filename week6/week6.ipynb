# %% [markdown]
# # Week 6 Deliverable

# %% [markdown]
# ## 1. Sample Data

# %%
# !wget -P data/ https://github.com/f0t1h/3M-february-2018/raw/refs/heads/master/3M-february-2018.txt.gz
# !gunzip data/3M-february-2018.txt.gz

# %%
# !tar -xzf data/toy_read_ref_set.tar.gz -C data/

# %%
# Out:
# --2025-11-12 03:41:55--  http://sample_data.zip/
# Resolving sample_data.zip (sample_data.zip)... failed: Name or service not known.
# wget: unable to resolve host address 'sample_data.zip'
# --2025-11-12 03:41:55--  https://app.box.com/index.php?rm=box_download_shared_file&shared_name=lx2xownlrhz3us8496tyu9c4dgade814
# Resolving app.box.com (app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to app.box.com (app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-11-12 03:41:55 ERROR 403: Forbidden.

# %% [markdown]
# ## 2. Align & quantify data to reference genome

# %% [markdown]
# ## 3. Cell clustering

# %% [markdown]
# ## 4. Cell annotation
